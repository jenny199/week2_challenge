# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("week2_dataset.xlsx")
df.head()
# Out:
#               Bearer Id               Start  Start ms                 End  \
# 0  13114483460844900352 2019-04-04 12:01:18     770.0 2019-04-25 14:35:31
# 1  13114483482878900224 2019-04-09 13:04:04     235.0 2019-04-25 08:15:48
# 2  13114483484080500736 2019-04-09 17:42:11       1.0 2019-04-25 11:58:13
# 3  13114483485442799616 2019-04-10 00:31:25     486.0 2019-04-25 07:36:35
# 4  13114483499480700928 2019-04-12 20:10:23     565.0 2019-04-25 10:40:32
#
#    End ms  Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0   662.0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1   606.0  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2   652.0  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3   171.0  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4   954.0  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#   Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# ...

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
IQR
Lower_Whisker = Q1-1.5*IQR
Upper_Whisker = Q3+1.5*IQR

# %%
#droping time stamp columns 
df1=df.drop(['Start', 'End'], axis=1)

# %%
#detecting outliers
print(df1 < (Q1 - 1.5 * IQR)) |(df1 > (Q3 + 1.5 * IQR))
# Out:
#         10 Kbps < UL TP < 50 Kbps (%)  250 Kbps < DL TP < 1 Mbps (%)  \
# 0                               False                          False
# 1                               False                          False
# 2                               False                          False
# 3                               False                          False
# 4                               False                          False
# ...                               ...                            ...
# 149996                          False                          False
# 149997                          False                          False
# 149998                          False                          False
# 149999                          False                          False
# 150000                          False                          False
#
#         50 Kbps < DL TP < 250 Kbps (%)  50 Kbps < UL TP < 300 Kbps (%)  \
# ...

# %%
df.describe()
# Out:
#             Start ms         End ms     Dur. (ms)          IMSI  \
# count  150000.000000  150000.000000  1.500000e+05  1.494310e+05
# mean      499.188200     498.800880  1.046086e+05  2.082016e+14
# std       288.611834     288.097653  8.103762e+04  2.148809e+10
# min         0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%       250.000000     251.000000  5.744050e+04  2.082014e+14
# 50%       499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%       749.000000     750.000000  1.324302e+05  2.082018e+14
# max       999.000000     999.000000  1.859336e+06  2.140743e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   1.489350e+05  1.494290e+05    122172.000000    122189.000000
# mean    4.188282e+10  4.847455e+13       109.795706        17.662883
# std     2.447443e+12  2.241637e+13       619.782739        84.793524
# min     3.360100e+10  4.400152e+11         0.000000         0.000000
# ...

# %%
#dealing with missing values in some columns
df['MSISDN/Number'].fillna(df['MSISDN/Number'].mean(), inplace = True)
df['Handset Type'].dropna(how='any', inplace=True)
df['Handset Manufacturer'].dropna(how='any', inplace=True)
# df['Bearer Id'].dropna(how='any', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 150001 non-null  object
#  1   Start                                     150000 non-null  datetime64[ns]
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  datetime64[ns]
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             150001 non-null  float64
#  8   IMEI                                      149429 non-null  float64
# ...

# %%
# top 10 handsets used by the customers.
df.groupby(['MSISDN/Number', 'Handset Type']).size().reset_index(name = 'Count').sort_values(by = 'Count', ascending = False).head(10)
# Out:
#         MSISDN/Number                       Handset Type  Count
# 106960   4.188282e+10                          undefined     56
# 106941   4.188282e+10       Samsung Galaxy S8 (Sm-G950F)     40
# 106881   4.188282e+10                   Huawei B528S-23A     25
# 106939   4.188282e+10       Samsung Galaxy S7 (Sm-G930X)     23
# 106868   4.188282e+10             Apple iPhone 7 (A1778)     22
# 106925   4.188282e+10        Samsung Galaxy J3 (Sm-J330)     20
# 13527    3.362632e+10        Samsung Galaxy J3 (Sm-J330)     18
# 106940   4.188282e+10  Samsung Galaxy S7 Edge (Sm-G935X)     18
# 6438     3.361489e+10        Samsung Galaxy J5 (Sm-J530)     17
# 13181    3.362578e+10           Samsung Galaxy A8 (2018)     17

# %%
#top 3 handset manufacturers
df.groupby(['Handset Manufacturer']).size().reset_index(name = 'Count').sort_values(by = 'Count', ascending = False).head(3)
# Out:
#     Handset Manufacturer  Count
# 5                  Apple  59565
# 103              Samsung  40839
# 52                Huawei  34423

# %%
#top5 handsets per handset manufactures
df.groupby(['Handset Manufacturer', 'Handset Type']).size().reset_index(name = 'Count').sort_values(by = 'Count', ascending = False).head(5)
# Out:
#      Handset Manufacturer             Handset Type  Count
# 316                Huawei         Huawei B528S-23A  19752
# 60                  Apple  Apple iPhone 6S (A1688)   9419
# 56                  Apple   Apple iPhone 6 (A1586)   9023
# 1395            undefined                undefined   8987
# 66                  Apple   Apple iPhone 7 (A1778)   6326

# %%
#group by users and get mean, max, min for the number of XDR sessions per each user.reset_index(name = 'Count').sort_values(by = 'Count', ascending = False)
xDR_sessions = df.groupby('MSISDN/Number').agg({'Bearer Id': ['count']})
xDR_sessions.columns = ['xDR_count']
xDR_sessions.head()
# Out:
#                xDR_count
# MSISDN/Number
# 3.360100e+10           1
# 3.360100e+10           1
# 3.360100e+10           1
# 3.360101e+10           1
# 3.360101e+10           2

# %%
#finding the total session duration of each user
tot_duration_per_user = df.groupby('MSISDN/Number').agg({'Dur. (ms).1': ['sum']})
tot_duration_per_user.columns = ['Total Session']
tot_duration_per_user.head()
# Out:
#                Total Session
# MSISDN/Number
# 3.360100e+10     116720140.0
# 3.360100e+10     181230963.0
# 3.360100e+10     134969374.0
# 3.360101e+10      49878024.0
# 3.360101e+10      37104453.0

# %%
#total download (DL) and upload (UL) data
df['Total_downloads'] = df['Total UL (Bytes)'] + df['Total DL (Bytes)']

# %%
tot_downloads = df.groupby('MSISDN/Number').agg({'Total_downloads': ['sum']})
tot_downloads.columns = ['Total Downloads']
tot_downloads.head()
# Out:
#                Total Downloads
# MSISDN/Number
# 3.360100e+10      8.786906e+08
# 3.360100e+10      1.568596e+08
# 3.360100e+10      5.959665e+08
# 3.360101e+10      4.223207e+08
# 3.360101e+10      1.457411e+09

# %%
# total data volume (in Bytes) during this session for each application
df['total_data_volume'] = df['Social Media DL (Bytes)'] + df['Social Media UL (Bytes)']
+df['Google DL (Bytes)'] + df['Google UL (Bytes)'] + df['Email DL (Bytes)']
+ df['Email UL (Bytes)'] + df['Youtube DL (Bytes)'] + df['Youtube UL (Bytes)'] + df['Netflix DL (Bytes)']
+ df['Netflix UL (Bytes)'] +df['Gaming DL (Bytes)'] + df['Gaming UL (Bytes)'] 
+ df['Other DL (Bytes)'] + df['Other UL (Bytes)']
# Out:
# 0         1.805588e+08
# 1         5.419594e+08
# 2         4.149084e+08
# 3         7.618372e+08
# 4         5.646198e+08
#               ...
# 149996    1.675193e+07
# 149997    7.146381e+08
# 149998    1.324156e+08
# 149999    8.161200e+08
# 150000    4.293653e+08
# Length: 150001, dtype: float64

# %%
total_data_volume = df.groupby('MSISDN/Number').agg({'total_data_volume': ['sum']})
total_data_volume.columns = ['Total Data Volume']
total_data_volume.head()
# Out:
#                Total Data Volume
# MSISDN/Number
# 3.360100e+10           2232135.0
# 3.360100e+10           2660565.0
# 3.360100e+10           3195623.0
# 3.360101e+10            280294.0
# 3.360101e+10           2912542.0

# %%
df['social Application'] =df['Social Media DL (Bytes)'] + df['Social Media UL (Bytes)']
social_application = df.groupby('MSISDN/Number').agg({'social Application': ['sum']})
social_application.columns = ['social Application']
social_application.head()
# Out:
#                social Application
# MSISDN/Number
# 3.360100e+10            2232135.0
# 3.360100e+10            2660565.0
# 3.360100e+10            3195623.0
# 3.360101e+10             280294.0
# 3.360101e+10            2912542.0

# %%
df['google Application'] =df['Google DL (Bytes)'] + df['Google UL (Bytes)']
google_application = df.groupby('MSISDN/Number').agg({'google Application': ['sum']})
google_application.columns = ['google Application']
google_application.head()
# Out:
#                google Application
# MSISDN/Number
# 3.360100e+10            4389005.0
# 3.360100e+10            5334863.0
# 3.360100e+10            3443126.0
# 3.360101e+10            9678493.0
# 3.360101e+10           18499616.0

# %%
df['email Application'] = df['Email DL (Bytes)']+df['Email UL (Bytes)']
google_application = df.groupby('MSISDN/Number').agg({'email Application': ['sum']})
google_application.columns = ['email Application']
google_application.head()
# Out:
#                email Application
# MSISDN/Number
# 3.360100e+10           1331362.0
# 3.360100e+10           3307781.0
# 3.360100e+10           3205380.0
# 3.360101e+10           2284670.0
# 3.360101e+10           3305469.0

# %%
df['youtube Application'] =  df['Youtube DL (Bytes)'] + df['Youtube UL (Bytes)']
google_application = df.groupby('MSISDN/Number').agg({'youtube Application': ['sum']})
google_application.columns = ['Youtube Application']
google_application.head()
# Out:
#                Youtube Application
# MSISDN/Number
# 3.360100e+10            21624548.0
# 3.360100e+10            12432223.0
# 3.360100e+10            21333570.0
# 3.360101e+10             6977321.0
# 3.360101e+10            41533002.0

# %%
df['netflix Application'] =  df['Netflix DL (Bytes)'] + df['Netflix UL (Bytes)']
google_application = df.groupby('MSISDN/Number').agg({'netflix Application': ['sum']})
google_application.columns = ['Netflix Application']
google_application.head()
# Out:
#                Netflix Application
# MSISDN/Number
# 3.360100e+10            27180981.0
# 3.360100e+10            11221763.0
# 3.360100e+10            19353900.0
# 3.360101e+10             1942092.0
# 3.360101e+10            49201724.0

# %%
df['gaming Application'] =  df['Gaming DL (Bytes)'] + df['Gaming UL (Bytes)'] 
google_application = df.groupby('MSISDN/Number').agg({'gaming Application': ['sum']})
google_application.columns = ['gaming Application']
google_application.head()
# Out:
#                gaming Application
# MSISDN/Number
# 3.360100e+10         8.124587e+08
# 3.360100e+10         1.197501e+08
# 3.360100e+10         5.388277e+08
# 3.360101e+10         3.911261e+08
# 3.360101e+10         1.314798e+09

# %%
df['other Application'] = df['Other DL (Bytes)'] + df['Other UL (Bytes)']
google_application = df.groupby('MSISDN/Number').agg({'other Application': ['sum']})
google_application.columns = ['other Application']
google_application.head()
# Out:
#                other Application
# MSISDN/Number
# 3.360100e+10         386570872.0
# 3.360100e+10         281710071.0
# 3.360100e+10         501693672.0
# 3.360101e+10          35279702.0
# 3.360101e+10         804804484.0

# %% [markdown]
# # Conducting a Graphical Univariate Analysis

# %%
#Graphical Univariate Analysis for total session per user
df['Dur. (ms).1'].sample(100).plot.hist(bins=20, figsize=(13, 6))

# %%
#Graphical Univariate Analysis for total session per user the total download (DL) and upload (UL) data
df['Total_downloads'].value_counts().head(10).plot.bar()

# %%
df['Bearer Id'].value_counts().head(10).plot.bar()

# %%
df['social Application'].value_counts().head(10).plot.bar()

# %%
df['google Application'].value_counts().head(10).plot.bar()

# %%
df['youtube Application'].value_counts().head(10).plot.bar()

# %%
df['netflix Application'].value_counts().head(10).plot.bar()

# %%
df['gaming Application'].sample(100).plot.hist(bins=20, figsize=(13, 6))

# %% [markdown]
# # Conducting a Non-Graphical Univariate Analysis

# %%
df['Dur. (ms).1'].describe()
# Out:
# count    1.500000e+05
# mean     1.046091e+08
# std      8.103761e+07
# min      7.142988e+06
# 25%      5.744079e+07
# 50%      8.639998e+07
# 75%      1.324308e+08
# max      1.859336e+09
# Name: Dur. (ms).1, dtype: float64

# %%
df['Total_downloads'].describe()
# Out:
# count    1.500000e+05
# mean     4.957646e+08
# std      2.443818e+08
# min      2.895611e+07
# 25%      2.844759e+08
# 50%      4.968611e+08
# 75%      7.065059e+08
# max      9.559848e+08
# Name: Total_downloads, dtype: float64

# %%
df['Bearer Id'].describe()
# Out:
# count     150001
# unique    134709
# top
# freq         991
# Name: Bearer Id, dtype: object

# %%
df['total_data_volume'].describe()
# Out:
# count    1.500010e+05
# mean     1.828250e+06
# std      1.035646e+06
# min      1.563000e+03
# 25%      9.322180e+05
# 50%      1.826471e+06
# 75%      2.727487e+06
# max      3.650861e+06
# Name: total_data_volume, dtype: float64

# %%
df['social Application'].describe()
# Out:
# count    1.500010e+05
# mean     1.828250e+06
# std      1.035646e+06
# min      1.563000e+03
# 25%      9.322180e+05
# 50%      1.826471e+06
# 75%      2.727487e+06
# max      3.650861e+06
# Name: social Application, dtype: float64

# %%
df['google Application'].describe()
# Out:
# count    1.500010e+05
# mean     7.807295e+06
# std      3.516420e+06
# min      4.033000e+04
# 25%      4.943599e+06
# 50%      7.812835e+06
# 75%      1.068280e+07
# max      1.552878e+07
# Name: google Application, dtype: float64

# %%
df['email Application'].describe()
# Out:
# count    1.500010e+05
# mean     2.259102e+06
# std      1.071109e+06
# min      8.359000e+03
# 25%      1.359344e+06
# 50%      2.263567e+06
# 75%      3.159818e+06
# max      4.518036e+06
# Name: email Application, dtype: float64

# %%
df['youtube Application'].describe()
# Out:
# count    1.500010e+05
# mean     2.264348e+07
# std      9.246800e+06
# min      7.890300e+04
# 25%      1.599846e+07
# 50%      2.266177e+07
# 75%      2.929260e+07
# max      4.519008e+07
# Name: youtube Application, dtype: float64

# %%
df['netflix Application'].describe()
# Out:
# count    1.500010e+05
# mean     2.262861e+07
# std      9.260820e+06
# min      9.843200e+04
# 25%      1.597946e+07
# 50%      2.263554e+07
# 75%      2.929044e+07
# max      4.519815e+07
# Name: netflix Application, dtype: float64

# %%
df['gaming Application'].describe()
# Out:
# count    1.500010e+05
# mean     4.303331e+08
# std      2.440199e+08
# min      3.063580e+05
# 25%      2.187279e+08
# 50%      4.316150e+08
# 75%      6.414159e+08
# max      8.592028e+08
# Name: gaming Application, dtype: float64

# %% [markdown]
# # Bivariate Analysis showing relationships between each application and total downloads

# %%
df.sample(500).plot.scatter(x='social Application', y='Total_downloads', colormap='viridis')

# %%
df.sample(500).plot.scatter(x='google Application', y='Total_downloads', colormap='viridis')

# %%
df.sample(500).plot.scatter(x='email Application', y='Total_downloads', colormap='viridis')

# %%
df.sample(500).plot.scatter(x='youtube Application', y='Total_downloads',c= 'black', colormap='viridis')

# %%
df.sample(500).plot.scatter(x='netflix Application', y='Total_downloads',c= 'black', colormap='viridis')

# %%
df.sample(500).plot.scatter(x='gaming Application', y='Total_downloads',c= 'black', colormap='viridis')

# %%
#matrix correlation
df['social Application'].corr(df['google Application'])
# Out:
# -0.0017082139338459314

# %%
df['email Application'].corr(df['youtube Application'])
# Out:
# -0.002918971213482336

# %%
df['netflix Application'].corr(df['gaming Application'])
# Out:
# -0.0031087454124693083

# %%
df[['social Application','google Application','email Application','youtube Application','netflix Application','gaming Application']].corr()
# Out:
#                      social Application  google Application  \
# social Application             1.000000           -0.001708
# google Application            -0.001708            1.000000
# email Application              0.004032           -0.000412
# youtube Application            0.000548            0.002277
# netflix Application            0.001013           -0.001902
# gaming Application             0.001082           -0.000994
#
#                      email Application  youtube Application  \
# social Application            0.004032             0.000548
# google Application           -0.000412             0.002277
# email Application             1.000000            -0.002919
# youtube Application          -0.002919             1.000000
# netflix Application           0.001029             0.002882
# gaming Application           -0.000644            -0.002999
#
#                      netflix Application  gaming Application
# ...

# %% [markdown]
# # Decile segmentation

# %%
#new dataframe with MSISDN and one engagement metric
df_users = df[['MSISDN/Number', 'Total_downloads']]

# %%
g1= df_users.groupby(['MSISDN/Number','Total_downloads']).sum().sort_values(by= 'Total_downloads')
g1.reset_index()
# Out:
#         MSISDN/Number  Total_downloads
# 0        3.369844e+10       28956107.0
# 1        3.366104e+10       31093346.0
# 2        3.365920e+10       33249009.0
# 3        3.366132e+10       33575840.0
# 4        3.366668e+10       33999624.0
# ...               ...              ...
# 148930   3.366783e+10      950760661.0
# 148931   3.365881e+10      951775502.0
# 148932   3.366855e+10      952307464.0
# 148933   3.366469e+10      952641334.0
# 148934   3.367492e+10      955984776.0
#
# [148935 rows x 2 columns]

# %%
#g1.columns = [['sum_downloads']]
g1.sort_values(by ='Total_downloads', ascending = False)
g1.reset_index()
# Out:
#         MSISDN/Number  Total_downloads
# 0        3.369844e+10       28956107.0
# 1        3.366104e+10       31093346.0
# 2        3.365920e+10       33249009.0
# 3        3.366132e+10       33575840.0
# 4        3.366668e+10       33999624.0
# ...               ...              ...
# 148930   3.366783e+10      950760661.0
# 148931   3.365881e+10      951775502.0
# 148932   3.366855e+10      952307464.0
# 148933   3.366469e+10      952641334.0
# 148934   3.367492e+10      955984776.0
#
# [148935 rows x 2 columns]

# %%
df['decile'] = pd.qcut(df['Dur. (ms).1'], 10, labels=False)

# %%
df[['Bearer Id', 'Dur. (ms).1', 'decile']].sort_values(by= 'decile', ascending = False).head(5)
# Out:
#                   Bearer Id   Dur. (ms).1  decile
# 0      13114483460844900352  1.823653e+09     9.0
# 51288  13114483551062401024  2.223303e+08     9.0
# 51300   7277825654144830464  2.744553e+08     9.0
# 51299   7349883248181130240  2.598738e+08     9.0
# 51298   7349883248179940352  2.543495e+08     9.0

# %% [markdown]
# # Dimensionality Reduction – perform a principal component analysis to reduce the dimensions of your data

# %%
#filling missing values
df['social Application'].fillna(value = df['social Application'].mean(), inplace = True)
df['email Application'].fillna(value = df['email Application'].mean(), inplace = True)
df['google Application'].fillna(value = df['google Application'].mean(), inplace = True)
df['youtube Application'].fillna(value = df['youtube Application'].mean(), inplace = True)
df['netflix Application'].fillna(value = df['netflix Application'].mean(), inplace = True)
df['gaming Application'].fillna(value = df['gaming Application'].mean(), inplace = True)
df['other Application'].fillna(value = df['other Application'].mean(), inplace = True)
df['Total_downloads'].fillna(value = df['Total_downloads'].mean(), inplace = True)
df['Dur. (ms).1'].fillna(value = df['Dur. (ms).1'].mean(), inplace = True)

# %%
from sklearn.preprocessing import StandardScaler
df_new = df[['Dur. (ms).1', 'Total_downloads', 'social Application', 'email Application', 'google Application',
             'youtube Application', 'netflix Application', 'gaming Application', 'other Application']]
x = StandardScaler().fit_transform(df_new)
x = pd.DataFrame(x, columns=['Dur. (ms).1', 'Total_downloads', 'social Application', 'email Application', 'google Application',
             'youtube Application', 'netflix Application', 'gaming Application', 'other Application'])

# %%
from sklearn.decomposition import PCA
pcamodel = PCA(n_components=5)
pca = pcamodel.fit_transform(x)
pca.shape
# Out:
# (150001, 5)

# %%
pcamodel.explained_variance_
# Out:
# array([1.99940027, 1.01099537, 1.00689154, 1.00395295, 1.00307484])

# %%
pcamodel.explained_variance_ratio_
# Out:
# array([0.22215411, 0.11233207, 0.11187609, 0.11154958, 0.11145202])

# %%
plt.bar(range(1,len(pcamodel.explained_variance_ )+1),pcamodel.explained_variance_ )
plt.ylabel('Explained variance')
plt.xlabel('Components')
plt.plot(range(1,len(pcamodel.explained_variance_ )+1),
         np.cumsum(pcamodel.explained_variance_),
         c='red',
         label="Cumulative Explained Variance")
plt.legend(loc='upper left')

# %%
plt.plot(pcamodel.explained_variance_ratio_)
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %%
#scree plot
plt.plot(pcamodel.explained_variance_)
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %%
plt.scatter(pca[:, 0], pca[:, 1])

# %%
#Effect of variables on each components
ax = sns.heatmap(pcamodel.components_,
                 cmap='YlGnBu',
                 yticklabels=[ "PCA"+str(x) for x in range(1,pcamodel.n_components_+1)],
                 xticklabels=list(x.columns),
                 cbar_kws={"orientation": "vertical"})
ax.set_aspect("equal")

# %%
def myplot(score,coeff,labels=None):
    xs = score[:,0]
    ys = score[:,1]
    n = coeff.shape[0]
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())
    plt.scatter(xs * scalex,ys * scaley,s=5)
    for i in range(n):
        plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
        if labels is None:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'green', ha = 'center', va = 'center')
        else:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, labels[i], color = 'g', ha = 'center', va = 'center')
 
    plt.xlabel("PC{}".format(1))
    plt.ylabel("PC{}".format(2))
    plt.grid()

myplot(pca[:,0:2],np.transpose(pcamodel.components_[0:2, :]),list(x.columns))
plt.show()

# %% [markdown]
# # User Engagement Analysis

# %%
#Top users per session number 
df["Session Number"] = df.groupby('MSISDN/Number')['Bearer Id'].transform("count" )
df[['MSISDN/Number','Session Number']].sort_values(by = 'Session Number', ascending= False).head(10)
# Out:
#         MSISDN/Number  Session Number
# 150000   4.188282e+10            1066
# 25790    4.188282e+10            1066
# 25728    4.188282e+10            1066
# 4684     4.188282e+10            1066
# 4686     4.188282e+10            1066
# 50867    4.188282e+10            1066
# 50875    4.188282e+10            1066
# 64635    4.188282e+10            1066
# 104318   4.188282e+10            1066
# 4718     4.188282e+10            1066

# %%
#Top 10 users engaged in session duration
df["session duration"] = df.groupby('MSISDN/Number')['Dur. (ms).1'].transform("sum" )
df[['MSISDN/Number','session duration']].sort_values(by = 'session duration', ascending= False).head(10)
# Out:
#         MSISDN/Number  session duration
# 150000   4.188282e+10      7.244694e+10
# 62194    4.188282e+10      7.244694e+10
# 58121    4.188282e+10      7.244694e+10
# 58263    4.188282e+10      7.244694e+10
# 58319    4.188282e+10      7.244694e+10
# 58825    4.188282e+10      7.244694e+10
# 59024    4.188282e+10      7.244694e+10
# 60746    4.188282e+10      7.244694e+10
# 60775    4.188282e+10      7.244694e+10
# 61270    4.188282e+10      7.244694e+10

# %%
#Top 10 customer engaged in downloads
df["Downloads engagement"] = df.groupby('MSISDN/Number')['Total_downloads'].transform("sum" )
df[['MSISDN/Number','Downloads engagement']].sort_values(by = 'Downloads engagement', ascending= False).head(10)
# Out:
#         MSISDN/Number  Downloads engagement
# 150000   4.188282e+10          5.312489e+11
# 31290    4.188282e+10          5.312489e+11
# 31639    4.188282e+10          5.312489e+11
# 116632   4.188282e+10          5.312489e+11
# 31755    4.188282e+10          5.312489e+11
# 116576   4.188282e+10          5.312489e+11
# 116432   4.188282e+10          5.312489e+11
# 32026    4.188282e+10          5.312489e+11
# 116304   4.188282e+10          5.312489e+11
# 32139    4.188282e+10          5.312489e+11

# %%
from sklearn import preprocessing
from sklearn.cluster import KMeans

# %%
# df['Total_downloads'].fillna(value = df['Total_downloads'].mean(), inplace = True)
# df['Dur. (ms).1'].fillna(value = df['Dur. (ms).1'].mean(), inplace = True)
df['Session Number'].fillna(value = df['Session Number'].mean(), inplace = True)

# %%
#normalizing the engagement metrics
x1= df[['Session Number','Dur. (ms).1', 'Total_downloads']]
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x1)
df_xscaled = pd.DataFrame(x_scaled,columns = ['xDr sessions', 'Session Duration', 'Total Downloads'])
df_xscaled.tail()
# Out:
#         xDr sessions  Session Duration  Total Downloads
# 149996      0.000000          0.040000         0.650301
# 149997      0.000939          0.049038         0.730105
# 149998      0.000000          0.049188         0.645873
# 149999      0.000000          0.049005         0.401893
# 150000      1.000000          0.052622         0.503553

# %%
#run k_mean
kmean = KMeans(n_clusters=3, init='k-means++', random_state=22)
kmean.fit(df_xscaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=22, tol=0.0001, verbose=0)

# %%
#appending kmean labels to a normalized dataframe of engagement metrics
df_xscaled['kmean_labels'] = kmeans.labels_
df_xscaled.tail()
# Out:
#         xDr sessions  Session Duration  Total Downloads  kmean_labels
# 149996      0.000000          0.040000         0.650301             1
# 149997      0.000939          0.049038         0.730105             0
# 149998      0.000000          0.049188         0.645873             1
# 149999      0.000000          0.049005         0.401893             1
# 150000      1.000000          0.052622         0.503553             1

# %%
#Compute the minimum, maximum, average & total non- normalized metrics for each cluster
x1['kmeans_labels'] = kmean.labels_
x1.head()
# Out:
# C:\Users\Jeannette\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Session Number   Dur. (ms).1  Total_downloads  kmeans_labels
# 0               2  1.823653e+09      345629377.0              2
# 1               2  1.365104e+09      707185356.0              0
# 2               1  1.361763e+09      307690973.0              2
# 3               1  1.321510e+09      889352748.0              0
# 4               1  1.089009e+09      607681403.0              1

# %%
#min, max,mean,sum for downloads metrics
downloads_metrics = x1.groupby('kmeans_labels').agg({'Total_downloads': ['min','max','mean','sum']})
downloads_metrics.reset_index()
# Out:
#   kmeans_labels Total_downloads
#                             min          max          mean           sum
# 0             0     635658221.0  955984776.0  7.771332e+08  3.898644e+13
# 1             1     353046011.0  635680346.0  4.947644e+08  2.482926e+13
# 2             2      28956107.0  353350506.0  2.124772e+08  1.054949e+13

# %%
#min, max,mean,sum for session duration metrics
session_metrics = x1.groupby('kmeans_labels').agg({'Dur. (ms).1': ['min','max','mean','sum']})
session_metrics.reset_index()
# Out:
#   kmeans_labels Dur. (ms).1
#                         min           max          mean           sum
# 0             0   7146574.0  1.859328e+09  1.044705e+08  5.240972e+12
# 1             1   7142988.0  1.772931e+09  1.048369e+08  5.261134e+12
# 2             2   7189000.0  1.859336e+09  1.045189e+08  5.189364e+12

# %%
#min, max,mean,sum for session number metrics
sessionnbr_metrics = x1.groupby('kmeans_labels').agg({'Dur. (ms).1': ['min','max','mean','count']})
sessionnbr_metrics.reset_index()
# Out:
#   kmeans_labels Dur. (ms).1
#                         min           max          mean  count
# 0             0   7146574.0  1.859328e+09  1.044705e+08  50167
# 1             1   7142988.0  1.772931e+09  1.048369e+08  50184
# 2             2   7189000.0  1.859336e+09  1.045189e+08  49650

# %%
download_cluster = df_xscaled.groupby('kmean_labels').agg({'Total Downloads': ['sum']})
download_cluster.columns = ['download Cluster']
download_cluster
# Out:
#               download Cluster
# kmean_labels
# 0                 25217.007050
# 1                 40485.009022
# 2                  9831.512239

# %%
#aggregating clusters per total downloads
download_cluster = df_xscaled.groupby('Total Downloads').agg({'kmean_labels': ['sum']})
download_cluster.columns = ['download Cluster']
download_cluster.head()
# Out:
#                  download Cluster
# Total Downloads
# 0.000000                        2
# 0.002305                        2
# 0.004631                        2
# 0.004983                        2
# 0.005441                        2

# %%
#aggregating clusters persession duration
session_cluster = df_xscaled.groupby('Session Duration').agg({'kmean_labels': ['sum']})
session_cluster.columns = ['Session Cluster']
session_cluster.head()
# Out:
#                   Session Cluster
# Session Duration
# 0.000000                        0
# 0.000002                        1
# 0.000025                        2
# 0.000038                        2
# 0.000062                        1

# %%
#user engagement distribution per cluster
sns.relplot(x='Total Downloads', y='Session Duration', height= 8, aspect=1, hue="kmean_labels", data= df_xscaled)

# %%
#Aggregate user total traffic per application
df.groupby('email Application').agg({'Total_downloads': ['sum']})
# Out:
#                   Total_downloads
#                               sum
# email Application
# 8359.0                924065299.0
# 13925.0               707266302.0
# 18176.0               202831181.0
# 21172.0               446814009.0
# 22402.0               736897628.0
# ...                           ...
# 4510915.0             543230798.0
# 4512730.0             586344182.0
# 4513000.0             526840714.0
# 4513579.0             492088698.0
# 4518036.0             694005112.0
#
# [147191 rows x 1 columns]

# %%
#group users in k engagement clusters based on the engagement metrics: 
n_cluster = [1,2,3,4,5,6,7,8,9]
kmean_out = []
for n in n_cluster:
    kmeans = KMeans(n_clusters=n, init='k-means++', random_state=22)
    kmeans.fit(df_xscaled)
    kmean_out.append(kmeans.inertia_)

# %%
kmean_out
# Out:
# [11768.203442071279,
#  3958.407406109493,
#  2510.1862696552566,
#  1518.744211645897,
#  1011.0842792737503,
#  778.0819562405297,
#  653.4335220184329,
#  575.6764049939783,
#  520.5496588079866]

# %%
# plot the cost against K values to check the optimal value
plt.plot(n_cluster, kmean_out, color ='g', linewidth ='3') 
plt.xlabel("Value of K") 
plt.ylabel("Sqaured Error (Cost)") 
plt.show()

# %% [markdown]
# # Experience Analytics

# %%
#handling missing values
df['TCP DL Retrans. Vol (Bytes)'].fillna(value = df['TCP DL Retrans. Vol (Bytes)'].mean(), inplace = True)
df['TCP UL Retrans. Vol (Bytes)'].fillna(value = df['TCP UL Retrans. Vol (Bytes)'].mean(), inplace = True)
df['Avg RTT DL (ms)'].fillna(value = df['Avg RTT DL (ms)'].mean(), inplace = True)
df['Avg RTT UL (ms)'].fillna(value = df['Avg RTT UL (ms)'].mean(), inplace = True)
df['Avg Bearer TP DL (kbps)'].fillna(value = df['Avg Bearer TP DL (kbps)'].mean(), inplace = True)
df['Avg Bearer TP UL (kbps)'].fillna(value = df['Avg Bearer TP UL (kbps)'].mean(), inplace = True)
df["Handset Type"].fillna("No Handset", inplace = True)

# %%
# aggregating user per average TCp retransmission
df['TCP retransmission'] = df['TCP DL Retrans. Vol (Bytes)'] + df['TCP UL Retrans. Vol (Bytes)']
tcp_retransmission = df.groupby('MSISDN/Number').agg({'TCP retransmission': ['sum']})
tcp_retransmission.head()
# Out:
#               TCP retransmission
#                              sum
# MSISDN/Number
# 3.360100e+10        2.156957e+07
# 3.360100e+10        2.156957e+07
# 3.360100e+10        2.156957e+07
# 3.360101e+10        7.607247e+05
# 3.360101e+10        3.094040e+07

# %%
#Aggregating user RTT transmission
df['RTT average'] = df['Avg RTT DL (ms)'] + df['Avg RTT UL (ms)']
RTT_average = df.groupby('MSISDN/Number').agg({'RTT average': ['sum']})
RTT_average.columns = ['RTT Average']
RTT_average.head()
# Out:
#                RTT Average
# MSISDN/Number
# 3.360100e+10     46.000000
# 3.360100e+10     31.000000
# 3.360100e+10    127.458589
# 3.360101e+10     84.000000
# 3.360101e+10    119.000000

# %%
#aggregating user per average throughput
df['Average Throughput'] = df['Avg Bearer TP DL (kbps)'] + df['Avg Bearer TP UL (kbps)']
throughput_average = df.groupby('MSISDN/Number').agg({'Average Throughput': ['sum']})
throughput_average.columns = ['Throughput Average']
throughput_average.head()
# Out:
#                Throughput Average
# MSISDN/Number
# 3.360100e+10                 76.0
# 3.360100e+10                 99.0
# 3.360100e+10                 97.0
# 3.360101e+10                248.0
# 3.360101e+10              56844.0

# %%
#outlier treatment with median on Tcp retransmission
print(df['TCP retransmission'].quantile(0.50)) 
print(df['TCP retransmission'].quantile(0.95)) 
df['TCP retransmission'] = np.where(df['TCP retransmission'] > 21569572.935152996, 21569572.935152996, df['TCP retransmission'])
# df.describe()
# Out:
# 21569572.935152996
# 21569572.935152996

# %%
#outlier treatment on average throughput
print(df['Average Throughput'].quantile(0.50)) 
print(df['Average Throughput'].quantile(0.95)) 
df['Average Throughput'] = np.where(df['Average Throughput'] > 71093, 125, df['Average Throughput'])
# df.describe()
# Out:
# 125.0
# 52206.0

# %%
#outlier treatment on average RTT
print(df['RTT average'].quantile(0.50)) 
print(df['RTT average'].quantile(0.95)) 
df['RTT average'] = np.where(df['RTT average'] > 273, 67, df['RTT average'])
df.describe()
# Out:
# 67.0
# 273.0
#             Start ms         End ms     Dur. (ms)          IMSI  \
# count  150000.000000  150000.000000  1.500000e+05  1.494310e+05
# mean      499.188200     498.800880  1.046086e+05  2.082016e+14
# std       288.611834     288.097653  8.103762e+04  2.148809e+10
# min         0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%       250.000000     251.000000  5.744050e+04  2.082014e+14
# 50%       499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%       749.000000     750.000000  1.324302e+05  2.082018e+14
# max       999.000000     999.000000  1.859336e+06  2.140743e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   1.489350e+05  1.494290e+05    150001.000000    150001.000000
# mean    4.188282e+10  4.847455e+13       109.795706        17.662883
# std     2.447443e+12  2.241637e+13       559.342620        76.529933
# min     3.360100e+10  4.400152e+11         0.000000         0.000000
# ...

# %%
#aggregating user per handset type
user_handset = df.groupby('MSISDN/Number').agg({'Handset Type': ['count']})
user_handset.columns = ['User Handset']
user_handset.tail()
# Out:
#                User Handset
# MSISDN/Number
# 3.379000e+10              1
# 4.188282e+10           1066
# 3.197021e+12              1
# 3.370000e+14              1
# 8.823971e+14              1

# %%
#Compute & list 10 of the top TCp transmission
tcp_retransmission.sort_values(by= 'Tcp Retransmition', ascending = False).head(10)
# Out:
#                Tcp Retransmition
# MSISDN/Number
# 3.366773e+10        8.354209e+09
# 3.365908e+10        7.941860e+09
# 3.366098e+10        7.374899e+09
# 3.376128e+10        6.043978e+09
# 3.376264e+10        5.879989e+09
# 3.365066e+10        5.593366e+09
# 3.366318e+10        5.566929e+09
# 3.366905e+10        5.195785e+09
# 3.376357e+10        5.179459e+09
# 3.365864e+10        5.165857e+09

# %%
#Compute & list 10 of the top, bottom and most frequent
tcp_retransmission.sort_values(by= 'Tcp Retransmition', ascending = False).tail(10)
# Out:
#                Tcp Retransmition
# MSISDN/Number
# 3.369969e+10               182.0
# 3.367937e+10               179.0
# 3.378420e+10               177.0
# 3.365068e+10               176.0
# 3.376964e+10               176.0
# 3.360783e+10               143.0
# 3.362636e+10               134.0
# 3.376206e+10               129.0
# 3.361478e+10               128.0
# 3.365013e+10                97.0

# %%
tcp_retransmission['Tcp Retransmition'].mode()
# Out:
# 0    2.156957e+07
# dtype: float64

# %%
#computing top10 RTT 
RTT_average.sort_values(by= 'RTT Average', ascending = False).head(10)
# Out:
#                  RTT Average
# MSISDN/Number
# 4.188282e+10   329526.164724
# 3.366232e+10    96924.000000
# 3.366087e+10    64670.000000
# 3.368369e+10    54848.000000
# 3.369855e+10    46021.000000
# 3.376181e+10    37084.000000
# 3.366879e+10    36304.000000
# 3.376094e+10    27278.000000
# 3.360679e+10    26300.000000
# 3.367182e+10    25715.000000

# %%
#computing bottom RTT
RTT_average.sort_values(by= 'RTT Average', ascending = False).tail(10)
# Out:
#                RTT Average
# MSISDN/Number
# 3.363468e+10          10.0
# 3.367220e+10           9.0
# 3.361085e+10           9.0
# 3.364768e+10           8.0
# 3.366862e+10           6.0
# 3.365949e+10           5.0
# 3.369505e+10           4.0
# 3.366020e+10           2.0
# 3.366158e+10           0.0
# 3.365298e+10           0.0

# %%
RTT_average['RTT Average'].mode()
# Out:
# 0    127.458589
# dtype: float64

# %%
#computing top 10 throughput
throughput_average.sort_values(by= 'Throughput Average', ascending = False).head(10)
# Out:
#                Throughput Average
# MSISDN/Number
# 4.188282e+10         1.807823e+07
# 3.376233e+10         9.022220e+05
# 3.366871e+10         8.404240e+05
# 3.365955e+10         7.983420e+05
# 3.366995e+10         6.908150e+05
# 3.366843e+10         6.768580e+05
# 3.369817e+10         6.187970e+05
# 3.362570e+10         5.641790e+05
# 3.365808e+10         5.503520e+05
# 3.376264e+10         5.496610e+05

# %%
throughput_average.sort_values(by= 'Throughput Average', ascending = False).tail(10)
# Out:
#                Throughput Average
# MSISDN/Number
# 3.366050e+10                  0.0
# 3.365096e+10                  0.0
# 3.363841e+10                  0.0
# 3.369859e+10                  0.0
# 3.375292e+10                  0.0
# 3.377746e+10                  0.0
# 3.377776e+10                  0.0
# 3.366062e+10                  0.0
# 3.366923e+10                  0.0
# 3.366087e+10                  0.0

# %%
throughput_average['Throughput Average'].mode()
# Out:
# 0    15.0
# dtype: float64

# %%
 #distribution of the average throughput  per handset type 
df.sample(500).plot.scatter(x='Handset Type', y='Average Throughput',c= 'black', colormap='viridis')

# %%
 #distribution of the TCP transmission per handset type 
df.sample(500).plot.scatter(x='Handset Type', y='TCP retransmission',c= 'black', colormap='viridis')

# %%
#Using the experience metrics above, perform a k-means clustering 
exp_metrics = df[['TCP retransmission', 'Average Throughput', 'RTT average']]
min_max_scaler = preprocessing.MinMaxScaler()
exp_metrics2 = min_max_scaler.fit_transform(exp_metrics)
df_exp_metrics2 = pd.DataFrame(exp_metrics2 ,columns = ['Norm TCP', 'Norm Throughpt', 'Norm RTT'])
df_exp_metrics2.head()
# Out:
#    Norm TCP  Norm Throughpt  Norm RTT
# 0  0.004965        0.000175  0.000485
# 1  0.004965        0.000110  0.000722
# 2  0.004965        0.000039  0.001315
# 3  0.004965        0.000230  0.001315
# 4  0.004965        0.000039  0.001315

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', random_state=22)
kmeans.fit(df_exp_metrics2)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=22, tol=0.0001, verbose=0)

# %%
#segment users into groups of experiences
df_exp_metrics2['kmean_label'] = kmeans.labels_
df_exp_metrics2.head()
# Out:
#    Norm TCP  Norm Throughpt  Norm RTT  kmean_label
# 0  0.004965        0.000175  0.000485            0
# 1  0.004965        0.000110  0.000722            0
# 2  0.004965        0.000039  0.001315            0
# 3  0.004965        0.000230  0.001315            0
# 4  0.004965        0.000039  0.001315            0

# %% [markdown]
# # Satisfaction Analysis

# %%
#counting value clusters to get the least one
df_xscaled['kmean_labels'].value_counts()
# Out:
# 1    50184
# 0    50167
# 2    49650
# Name: kmean_labels, dtype: int64

# %%
#cluster center for the least cluster 2 of engagement metrics
cluster_center = kmean.cluster_centers_[:,2]
cluster_center
# Out:
# array([0.50247457, 0.80707002, 0.19796702])

# %%
from scipy.spatial import distance

# %%
#function to calculate the euclidian distance
def calculate_distance(centroid, X, Y,Z):
    distances = []
    # Unpack the x and y coordinates of the centroid
    c_x, c_y,c_z = centroid
    # Iterate over the data points and calculate the distance using the           # given formula
    for x, y,z in list(zip(X, Y,Z)):
        root_diff_x = (x - c_x) ** 2
        root_diff_y = (y - c_y) ** 2
        root_diff_z = (z - c_z) ** 2
        distance = np.sqrt(root_diff_x + root_diff_y + root_diff_z)
        distances.append(distance)
    return distances

# %%
x['Engagement Score'] = calculate_distance(cluster_center, x['Session Number'], x['Dur. (ms).1'],x['Total_downloads'])
x.head()
# Out:
# C:\Users\Jeannette\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    Session Number   Dur. (ms).1  Total_downloads  \
# 0               2  1.823653e+09      345629377.0
# 1               2  1.365104e+09      707185356.0
# 2               1  1.361763e+09      307690973.0
# 3               1  1.321510e+09      889352748.0
# 4               1  1.089009e+09      607681403.0
#
#    engagement_Euclidean_Distance  Engagement Score
# 0                   1.856117e+09      1.856117e+09
# 1                   1.537407e+09      1.537407e+09
# 2                   1.396091e+09      1.396091e+09
# 3                   1.592902e+09      1.592902e+09
# ...

# %%
df_exp_metrics2['kmean_label'].value_counts()
# Out:
# 0    111723
# 2     30014
# 1      8264
# Name: kmean_label, dtype: int64

# %%
#cluster center for the least cluster 2 of experience score
cluster_center1 = kmeans.cluster_centers_[:,1]
cluster_center1
# Out:
# array([0.00552235, 0.25112698, 0.10720593])

# %%
#experience score
exp_metrics['Experience Score'] = calculate_distance(cluster_center1, exp_metrics['TCP retransmission'], exp_metrics['Average Throughput'],exp_metrics['RTT average'])
exp_metrics.tail()
# Out:
# C:\Users\Jeannette\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         TCP retransmission  Average Throughput  RTT average  Experience Score
# 149996        2.156957e+07          117.000000    32.000000      2.156957e+07
# 149997        2.156957e+07           77.000000    29.000000      2.156957e+07
# 149998        2.156957e+07           90.000000    49.000000      2.156957e+07
# 149999        2.156957e+07           71.000000    42.000000      2.156957e+07
# 150000        2.156957e+07        15070.474573   127.458589      2.156958e+07

# %%
#combing the two data frame
new_df= pd.concat([df['MSISDN/Number'], x, exp_metrics ], axis=1)
new_df.head()
# Out:
#    MSISDN/Number  Session Number   Dur. (ms).1  Total_downloads  \
# 0   3.366496e+10               2  1.823653e+09      345629377.0
# 1   3.368185e+10               2  1.365104e+09      707185356.0
# 2   3.376063e+10               1  1.361763e+09      307690973.0
# 3   3.375034e+10               1  1.321510e+09      889352748.0
# 4   3.369980e+10               1  1.089009e+09      607681403.0
#
#    engagement_Euclidean_Distance  Engagement Score  TCP retransmission  \
# 0                   1.856117e+09      1.856117e+09        2.156957e+07
# 1                   1.537407e+09      1.537407e+09        2.156957e+07
# 2                   1.396091e+09      1.396091e+09        2.156957e+07
# 3                   1.592902e+09      1.592902e+09        2.156957e+07
# 4                   1.247084e+09      1.247084e+09        2.156957e+07
#
#    Average Throughput  RTT average  Experience Score
# 0                67.0    47.000000      2.156957e+07
# ...

# %%
#finding the satsifaction score as the average og the two score
new_df['Satisfaction Score'] = (new_df['Engagement Score'] + new_df['Experience Score'])/2
new_df
# Out:
#         MSISDN/Number  Session Number   Dur. (ms).1  Total_downloads  \
# 0        3.366496e+10               2  1.823653e+09     3.456294e+08
# 1        3.368185e+10               2  1.365104e+09     7.071854e+08
# 2        3.376063e+10               1  1.361763e+09     3.076910e+08
# 3        3.375034e+10               1  1.321510e+09     8.893527e+08
# 4        3.369980e+10               1  1.089009e+09     6.076814e+08
# ...               ...             ...           ...              ...
# 149996   3.365069e+10               1  8.123076e+07     6.318041e+08
# 149997   3.366345e+10               2  9.797070e+07     7.057839e+08
# 149998   3.362189e+10               1  9.824953e+07     6.276986e+08
# 149999   3.361962e+10               1  9.791063e+07     4.015220e+08
# 150000   4.188282e+10            1066  1.046091e+08     4.957646e+08
#
#         engagement_Euclidean_Distance  Engagement Score  TCP retransmission  \
# ...

# %%
#outlier treatment on engagement score
print(new_df['Engagement Score'].quantile(0.50)) 
print(new_df['Engagement Score'].quantile(0.95)) 
new_df['Engagement Score'] = np.where(new_df['Engagement Score'] > 125, 125, new_df['Engagement Score'])
# Out:
# 125.0
# 125.0

# %%
#outlier treatment on experience
print(new_df['Experience Score'].quantile(0.50)) 
print(new_df['Experience Score'].quantile(0.95)) 
new_df['Experience Score'] = np.where(new_df['Experience Score'] > 21569573.0376301, 21569572.929829612, new_df['Experience Score'])
# Out:
# 21569572.929829612
# 21569573.0376301

# %%
print(new_df['Satisfaction Score'].quantile(0.50)) 
print(new_df['Satisfaction Score'].quantile(0.95)) 
new_df['satisfaction Score'] = np.where(new_df['Satisfaction Score'] > 452272060.8911113, 265777679.33524364, new_df['Satisfaction Score'])
# Out:
# 265777679.33524364
# 452272060.8911113

# %%
#top 10 satisfied customer 
new_df.sort_values(by = 'Satisfaction Score', ascending = False).head(10)
# Out:
#         MSISDN/Number  Session Number  Dur. (ms).1  Total_downloads  \
# 67481    3.366613e+10               1   86400014.0      918735400.0
# 41182    3.365863e+10               1   86399996.0      830836588.0
# 122572   3.365908e+10               3   86399920.0      823257151.0
# 77950    3.376211e+10               2   86201691.0      616169613.0
# 39608    3.366491e+10               1   78285846.0      618272906.0
# 34636    3.366045e+10               2   86399957.0      536270193.0
# 65135    4.188282e+10            1066   86389072.0      695104772.0
# 119416   3.366682e+10               1   86400016.0      841012176.0
# 3741     3.365871e+10               1   86399950.0      516133932.0
# 78810    3.366486e+10               5   86399970.0      871264494.0
#
#         engagement_Euclidean_Distance  Engagement Score  TCP retransmission  \
# 67481                    9.227891e+08             125.0        4.211258e+09
# ...

# %%
#attributes and labels for prediction 
X = new_df['Engagement Score'].values.reshape(-1,1)
Y = new_df['Satisfaction Score'].values.reshape(-1,1)

# %%
#split data into training and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
#training the linear regression model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#To get the intercept:
print(regressor.intercept_)
#For getting the slope:
print(regressor.coef_)
# Out:
# [2.68886845e+08]
# [[0.]]

# %%
y_pred = regressor.predict(X_test)

# %%
#comparing the actual value and the predicted value
df_comp = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df_comp
# Out:
#              Actual     Predicted
# 0      3.418299e+08  2.688868e+08
# 1      6.061812e+07  2.688868e+08
# 2      3.557779e+08  2.688868e+08
# 3      4.487552e+08  2.688868e+08
# 4      3.343836e+08  2.688868e+08
# ...             ...           ...
# 29996  2.662099e+08  2.688868e+08
# 29997  8.113540e+07  2.688868e+08
# 29998  1.403251e+08  2.688868e+08
# 29999  3.563109e+08  2.688868e+08
# 30000  1.199977e+08  2.688868e+08
#
# [30001 rows x 2 columns]

# %%
#visualizing the comparison graph with just 25 first element
df_comp1 = df_comp.head(25)
df_comp1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title("Bar graph showing the comparison of Actual and Predicted values.")
plt.show()

# %%
#plot shows straight line with the test data 
plt.scatter(X_test, y_test,  color='gray')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %%
#Run a k-means (k=2) on the engagement & the experience score 
engage_expDf = new_df[['Engagement Score', 'Experience Score']]
min_max_scaler = preprocessing.MinMaxScaler()
engage_exp = min_max_scaler.fit_transform(engage_expDf)
engage_exp
engage_normexpDf = pd.DataFrame(engage_exp ,columns = ['Engagement scoreNorm', 'Experience scoreNorm'])
engage_normexpDf.head()
# Out:
#    Engagement scoreNorm  Experience scoreNorm
# 0              0.897950              0.004965
# 1              0.739763              0.004965
# 2              0.669623              0.004965
# 3              0.767307              0.004965
# 4              0.595665              0.004965

# %%
#run k_mean
kmean1 = KMeans(n_clusters=2, init='k-means++', random_state=22)
kmean1.fit(engage_normexpDf)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=22, tol=0.0001, verbose=0)

# %%
engage_normexpDf['score_clusters'] =  kmean1.labels_
engage_normexpDf.head()
# Out:
#    Engagement scoreNorm  Experience scoreNorm  score_clusters
# 0              0.897950              0.004965               0
# 1              0.739763              0.004965               0
# 2              0.669623              0.004965               0
# 3              0.767307              0.004965               0
# 4              0.595665              0.004965               0

# %%
#Aggregate the average satisfaction & experience score per cluster
new_df['score_cluster'] = kmean.labels_
aggregation1 = new_df.groupby(['score_cluster']).agg({'Experience Score': ['sum']})
aggregation1.reset_index()
# Out:
#   score_cluster Experience Score
#                              sum
# 0             0     1.071012e+12
# 1             1     1.078001e+12

# %%
aggregation2 = new_df.groupby(['score_cluster']).agg({'Satisfaction Score': ['sum']})
aggregation2.reset_index()
# Out:
#   score_cluster Satisfaction Score
#                                sum
# 0             0       5.355104e+11
# 1             1       5.390053e+11
